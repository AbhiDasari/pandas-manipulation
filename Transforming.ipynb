# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("pittsburgh2013.csv")

# %%
data.head(10)
# Out:
#         Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0   2013-1-1                32                 28                21
# 1   2013-1-2                25                 21                17
# 2   2013-1-3                32                 24                16
# 3   2013-1-4                30                 28                27
# 4   2013-1-5                34                 30                25
# 5   2013-1-6                37                 34                32
# 6   2013-1-7                33                 29                25
# 7   2013-1-8                43                 31                19
# 8   2013-1-9                45                 36                28
# 9  2013-1-10                41                 34                30
#
#    Max Dew PointF  Mean Dew PointF  Min DewpointF  Max Humidity  \
# 0              30               27             16           100
# 1              14               12             10            77
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'Mean Dew PointF', 'Min DewpointF', 'Max Humidity',
#        'Mean Humidity', 'Min Humidity', 'Max Sea Level PressureIn',
#        'Mean Sea Level PressureIn', 'Min Sea Level PressureIn',
#        'Max VisibilityMiles', 'Mean VisibilityMiles', 'Min VisibilityMiles',
#        'Max Wind SpeedMPH', 'Mean Wind SpeedMPH', 'Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', 'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
def to_celsius(F):
    return int(5/9*(F - 32))
data['Max TemperatureC']=data['Max TemperatureF'].apply(to_celsius)

# %%
data.head(10)
# Out:
#         Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0   2013-1-1                32                 28                21
# 1   2013-1-2                25                 21                17
# 2   2013-1-3                32                 24                16
# 3   2013-1-4                30                 28                27
# 4   2013-1-5                34                 30                25
# 5   2013-1-6                37                 34                32
# 6   2013-1-7                33                 29                25
# 7   2013-1-8                43                 31                19
# 8   2013-1-9                45                 36                28
# 9  2013-1-10                41                 34                30
#
#    Max Dew PointF  Mean Dew PointF  Min DewpointF  Max Humidity  \
# 0              30               27             16           100
# 1              14               12             10            77
# ...

# %%
dictw={'Rain': "10101" ,'Snow': "01010"}
data["dictw"]=data["Events"].map(dictw)

# %%
data.head(10)
# Out:
#         Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0   2013-1-1                32                 28                21
# 1   2013-1-2                25                 21                17
# 2   2013-1-3                32                 24                16
# 3   2013-1-4                30                 28                27
# 4   2013-1-5                34                 30                25
# 5   2013-1-6                37                 34                32
# 6   2013-1-7                33                 29                25
# 7   2013-1-8                43                 31                19
# 8   2013-1-9                45                 36                28
# 9  2013-1-10                41                 34                30
#
#    Max Dew PointF  Mean Dew PointF  Min DewpointF  Max Humidity  \
# 0              30               27             16           100
# 1              14               12             10            77
# ...
