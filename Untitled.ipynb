# %%
import pandas as pd
data=pd.read_csv("pennsylvania2012_turnout.csv")

# %%
data.head(67)
# Out:
#           county state   total      Obama     Romney  winner  voters  \
# 0          Adams    PA   41973  35.482334  63.112001  Romney   61156
# 1      Allegheny    PA  614671  56.640219  42.185820   Obama  924351
# 2      Armstrong    PA   28322  30.696985  67.901278  Romney   42147
# 3         Beaver    PA   80015  46.032619  52.637630  Romney  115157
# 4        Bedford    PA   21444  22.057452  76.986570  Romney   32189
# ..           ...   ...     ...        ...        ...     ...     ...
# 62    Washington    PA   90078  42.744066  56.012567  Romney  142331
# 63         Wayne    PA   20966  38.815225  59.768196  Romney   32577
# 64  Westmoreland    PA  168709  37.567646  61.306154  Romney  238006
# 65       Wyoming    PA   11214  42.910647  55.189941  Romney   17255
# 66          York    PA  186394  38.695452  59.860296  Romney  280280
#
#       turnout     margin
# 0   68.632677  27.629667
# 1   66.497575  14.454399
# 2   67.198140  37.204293
# 3   69.483401   6.605012
# ...

# %%
data.loc[4,"winner"]
# Out:
# 'Romney'

# %%
data=data.set_index('county')

# %%
data.index.values
# Out:
# array(['Adams', 'Allegheny', 'Armstrong', 'Beaver', 'Bedford', 'Berks',
#        'Blair', 'Bradford', 'Bucks', 'Butler', 'Cambria', 'Cameron',
#        'Carbon', 'Centre', 'Chester', 'Clarion', 'Clearfield', 'Clinton',
#        'Columbia', 'Crawford', 'Cumberland', 'Dauphin', 'Delaware', 'Elk',
#        'Erie', 'Fayette', 'Forest', 'Franklin', 'Fulton', 'Greene',
#        'Huntingdon', 'Indiana', 'Jefferson', 'Juniata', 'Lackawanna',
#        'Lancaster', 'Lawrence', 'Lebanon', 'Lehigh', 'Luzerne',
#        'Lycoming', 'McKean', 'Mercer', 'Mifflin', 'Monroe', 'Montgomery',
#        'Montour', 'Northampton', 'Northumberland', 'Perry',
#        'Philadelphia', 'Pike', 'Potter', 'Schuylkill', 'Snyder',
#        'Somerset', 'Sullivan', 'Susquehanna', 'Tioga', 'Union', 'Venango',
#        'Warren', 'Washington', 'Wayne', 'Westmoreland', 'Wyoming', 'York'],
#       dtype=object)

# %%
data.loc["Potter":"Perry":-1,::-1]
# Out:
#                  margin    turnout   voters  winner     Romney      Obama  \
# county
# Potter        45.898681  66.022175    10913  Romney  72.158223  26.259542
# Pike          10.978242  55.363289    41840  Romney  54.882576  43.904334
# Philadelphia  71.172800  59.461407  1099197   Obama  14.051451  85.224251
# Perry         38.821272  66.948064    27245  Romney  68.591009  29.769737
#
#                total state
# county
# Potter          7205    PA
# Pike           23164    PA
# Philadelphia  653598    PA
# Perry          18240    PA

# %%
filter=data.turnout>70
data[filter]
# Out:
#              state   total      Obama     Romney  winner  voters    turnout  \
# county
# Bucks           PA  319407  49.966970  48.801686   Obama  435606  73.324748
# Butler          PA   88924  31.920516  66.816607  Romney  122762  72.436096
# Chester         PA  248295  49.228539  49.650617  Romney  337822  73.498766
# Forest          PA    2308  38.734835  59.835355  Romney    3232  71.410891
# Franklin        PA   62802  30.110506  68.583803  Romney   87406  71.850903
# Montgomery      PA  401787  56.637223  42.286834   Obama  551105  72.905708
# Westmoreland    PA  168709  37.567646  61.306154  Romney  238006  70.884347
#
#                  margin
# county
# Bucks          1.165284
# Butler        34.896091
# Chester        0.422079
# Forest        21.100520
# Franklin      38.473297
# Montgomery    14.350390
# Westmoreland  23.738508

# %%
import numpy as np

# %%
filter=data.margin<1

data.loc[filter,'winner']= np.nan
data[filter]
# Out:
#         state   total      Obama     Romney winner  voters    turnout  \
# county
# Berks      PA  163253  48.939376  49.528646    NaN  250356  65.208343
# Centre     PA   68801  48.948416  48.977486    NaN  112949  60.913333
# Chester    PA  248295  49.228539  49.650617    NaN  337822  73.498766
#
#            margin
# county
# Berks    0.589269
# Centre   0.029069
# Chester  0.422079
