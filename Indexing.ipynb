# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("users.csv")

# %%
data.shape
# Out:
# (4, 5)

# %%
data.head()
# Out:
#    Unnamed: 0 weekday    city  visitors  signups
# 0           0     Sun  Austin       139        7
# 1           1     Sun  Dallas       237       12
# 2           2     Mon  Austin       326        3
# 3           3     Mon  Dallas       456        5

# %%
del data["Unnamed: 0"]

# %%
data.head()
# Out:
#   weekday    city  visitors  signups
# 0     Sun  Austin       139        7
# 1     Sun  Dallas       237       12
# 2     Mon  Austin       326        3
# 3     Mon  Dallas       456        5

# %%
data.index.name='Index Number'
data.columns.name="Visitors"

# %%
data.head()
# Out:
# Visitors     weekday    city  visitors  signups
# Index Number
# 0                Sun  Austin       139        7
# 1                Sun  Dallas       237       12
# 2                Mon  Austin       326        3
# 3                Mon  Dallas       456        5

# %%
data=pd.read_csv("all_medalists.csv")

# %%
data.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
data=data.set_index(["Edition","Sport"])
data.sort_index()
# Out:
#                       City       Discipline               Athlete  NOC Gender  \
# Edition Sport
# 1896    Aquatics    Athens         Swimming         HAJOS, Alfred  HUN    Men
#         Aquatics    Athens         Swimming      HERSCHMANN, Otto  AUT    Men
#         Aquatics    Athens         Swimming     DRIVAS, Dimitrios  GRE    Men
#         Aquatics    Athens         Swimming    MALOKINIS, Ioannis  GRE    Men
#         Aquatics    Athens         Swimming    CHASAPIS, Spiridon  GRE    Men
# ...                    ...              ...                   ...  ...    ...
# 2008    Wrestling  Beijing  Wrestling Gre-R        ENGLICH, Mirko  GER    Men
#         Wrestling  Beijing  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU    Men
#         Wrestling  Beijing  Wrestling Gre-R       PATRIKEEV, Yuri  ARM    Men
#         Wrestling  Beijing  Wrestling Gre-R         LOPEZ, Mijain  CUB    Men
#         Wrestling  Beijing  Wrestling Gre-R        BAROEV, Khasan  RUS    Men
#
# ...

# %%
data.loc[2008,:]
# Out:
#               City       Discipline               Athlete  NOC Gender  \
# Sport
# Aquatics   Beijing           Diving        GALPERIN, Gleb  RUS    Men
# Aquatics   Beijing           Diving      MITCHAM, Matthew  AUS    Men
# Aquatics   Beijing           Diving           ZHOU, Luxin  CHN    Men
# Aquatics   Beijing           Diving             WANG, Xin  CHN  Women
# Aquatics   Beijing           Diving          CHEN, Ruolin  CHN  Women
# ...            ...              ...                   ...  ...    ...
# Wrestling  Beijing  Wrestling Gre-R        ENGLICH, Mirko  GER    Men
# Wrestling  Beijing  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU    Men
# Wrestling  Beijing  Wrestling Gre-R       PATRIKEEV, Yuri  ARM    Men
# Wrestling  Beijing  Wrestling Gre-R         LOPEZ, Mijain  CUB    Men
# Wrestling  Beijing  Wrestling Gre-R        BAROEV, Khasan  RUS    Men
#
#                   Event Event_gender   Medal
# Sport
# Aquatics   10m platform            M  Bronze
# ...

# %%
data.loc[(slice(None),['Wrestling',"Aquatics"]),:]
# Out:
#                       City       Discipline               Athlete  NOC Gender  \
# Edition Sport
# 1896    Aquatics    Athens         Swimming         HAJOS, Alfred  HUN    Men
#         Aquatics    Athens         Swimming      HERSCHMANN, Otto  AUT    Men
#         Aquatics    Athens         Swimming     DRIVAS, Dimitrios  GRE    Men
#         Aquatics    Athens         Swimming    MALOKINIS, Ioannis  GRE    Men
#         Aquatics    Athens         Swimming    CHASAPIS, Spiridon  GRE    Men
# ...                    ...              ...                   ...  ...    ...
# 2008    Wrestling  Beijing  Wrestling Gre-R        ENGLICH, Mirko  GER    Men
#         Wrestling  Beijing  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU    Men
#         Wrestling  Beijing  Wrestling Gre-R       PATRIKEEV, Yuri  ARM    Men
#         Wrestling  Beijing  Wrestling Gre-R         LOPEZ, Mijain  CUB    Men
#         Wrestling  Beijing  Wrestling Gre-R        BAROEV, Khasan  RUS    Men
#
# ...

# %%
data.pivot(index=data["Athlete"].unique(),columns="Event",values="Discipline")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-7ebfaa33212d> in <module>
# ----> 1 data.pivot(index=data["Athlete"].unique(),columns="Event",values="Discipline")
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5910         from pandas.core.reshape.pivot import pivot
#    5911
# -> 5912         return pivot(self, index=index, columns=columns, values=values)
#    5913
#    5914     _shared_docs[
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     418             index = data.index
#     419         else:
# --> 420             index = data[index]
#     421         index = MultiIndex.from_arrays([index, data[columns]])
#     422
#
# ...
